# %%
#import required libraries
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#read data through Pandas
df=pd.read_csv('PS4_GamesSales.csv', encoding='utf-8',encoding_errors='replace')

# %%
df
# Out:
#                                     Game    Year             Genre  \
# 0                     Grand Theft Auto V  2014.0            Action
# 1              Call of Duty: Black Ops 3  2015.0           Shooter
# 2                  Red Dead Redemption 2  2018.0  Action-Adventure
# 3                     Call of Duty: WWII  2017.0           Shooter
# 4                                FIFA 18  2017.0            Sports
# ...                                  ...     ...               ...
# 1029  Fallen Legion: Flames of Rebellion     NaN      Role-Playing
# 1030            Radial G Racing Revolved  2017.0            Racing
# 1031                The Mummy Demastered     NaN            Action
# 1032          Project Nimbus: Code Mirai     NaN            Action
# 1033                 Battle Chef Brigade     NaN            Action
#
#            Publisher  North America  Europe  Japan  Rest of World  Global
# 0     Rockstar Games           6.06    9.71   0.60           3.02   19.39
# ...

# %%
#checking that how many rows and columns in given dataset
df.shape
# Out:
# (1034, 9)

# %%
#Getting ALl Information About Our Dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Game           1034 non-null   object
#  1   Year           825 non-null    float64
#  2   Genre          1034 non-null   object
#  3   Publisher      825 non-null    object
#  4   North America  1034 non-null   float64
#  5   Europe         1034 non-null   float64
#  6   Japan          1034 non-null   float64
#  7   Rest of World  1034 non-null   float64
#  8   Global         1034 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 72.8+ KB

# %%
#find the data type for each column
df.dtypes
# Out:
# Game              object
# Year             float64
# Genre             object
# Publisher         object
# North America    float64
# Europe           float64
# Japan            float64
# Rest of World    float64
# Global           float64
# dtype: object

# %%
#Checking the null values
df.isnull().sum()
# Out:
# Game               0
# Year             209
# Genre              0
# Publisher        209
# North America      0
# Europe             0
# Japan              0
# Rest of World      0
# Global             0
# dtype: int64

# %%
#Count observations for each column
df.count()
# Out:
# Game             1034
# Year              825
# Genre            1034
# Publisher         825
# North America    1034
# Europe           1034
# Japan            1034
# Rest of World    1034
# Global           1034
# dtype: int64

# %%
#Get Overall Statistics About the Dataframe
df.describe()
# Out:
#               Year  North America       Europe        Japan  Rest of World  \
# count   825.000000    1034.000000  1034.000000  1034.000000    1034.000000
# mean   2015.966061       0.204613     0.248714     0.033636       0.089014
# std       1.298360       0.563471     0.785491     0.108344       0.249410
# min    2013.000000       0.000000     0.000000     0.000000       0.000000
# 25%    2015.000000       0.000000     0.000000     0.000000       0.000000
# 50%    2016.000000       0.020000     0.000000     0.000000       0.010000
# 75%    2017.000000       0.120000     0.130000     0.030000       0.050000
# max    2020.000000       6.180000     9.710000     2.170000       3.020000
#
#             Global
# count  1034.000000
# mean      0.576054
# std       1.583534
# min       0.000000
# 25%       0.000000
# 50%       0.060000
# 75%       0.357500
# max      19.390000

# %%
#Checking the duplicate values in dataframe
df.duplicated().sum()
# Out:
# 0

# %%
## Dropping the missing values.
df=df.dropna()

# %%
#dataframe after dropping the missing values
df
# Out:
#                            Game    Year             Genre  \
# 0            Grand Theft Auto V  2014.0            Action
# 1     Call of Duty: Black Ops 3  2015.0           Shooter
# 2         Red Dead Redemption 2  2018.0  Action-Adventure
# 3            Call of Duty: WWII  2017.0           Shooter
# 4                       FIFA 18  2017.0            Sports
# ...                         ...     ...               ...
# 1025                  Biomutant  2019.0            Action
# 1026                    de Blob  2017.0          Platform
# 1027           Chaos on Deponia  2017.0         Adventure
# 1028                  Code Vein  2018.0            Action
# 1030   Radial G Racing Revolved  2017.0            Racing
#
#                        Publisher  North America  Europe  Japan  Rest of World  \
# 0                 Rockstar Games           6.06    9.71   0.60           3.02
# 1                     Activision           6.18    6.05   0.41           2.44
# ...

# %%
#Count the no.of abservations for each column after dropiing the missing values
df.count()
# Out:
# Game             825
# Year             825
# Genre            825
# Publisher        825
# North America    825
# Europe           825
# Japan            825
# Rest of World    825
# Global           825
# dtype: int64

# %%
# Overall Statistics for the dataframe after dropping the null values
df.describe()
# Out:
#               Year  North America      Europe       Japan  Rest of World  \
# count   825.000000     825.000000  825.000000  825.000000     825.000000
# mean   2015.966061       0.256448    0.311600    0.042048       0.111552
# std       1.298360       0.620259    0.868271    0.119814       0.274713
# min    2013.000000       0.000000    0.000000    0.000000       0.000000
# 25%    2015.000000       0.000000    0.000000    0.000000       0.000000
# 50%    2016.000000       0.050000    0.020000    0.000000       0.020000
# 75%    2017.000000       0.190000    0.220000    0.040000       0.090000
# max    2020.000000       6.180000    9.710000    2.170000       3.020000
#
#            Global
# count  825.000000
# mean     0.721721
# std      1.743122
# min      0.000000
# 25%      0.030000
# 50%      0.120000
# 75%      0.560000
# max     19.390000

# %%
#1.Identify the top 5 best-selling games globally

# %%
df['Game'].unique()
# Out:
# array(['Grand Theft Auto V', 'Call of Duty: Black Ops 3',
#        'Red Dead Redemption 2', 'Call of Duty: WWII', 'FIFA 18',
#        'FIFA 17', 'Uncharted (PS4)', 'Spider-Man (PS4)',
#        'Call of Duty: Infinite Warfare', 'Fallout 4', 'FIFA 16',
#        'Star Wars Battlefront 2015', 'Call of Duty: Advanced Warfare',
#        'Battlefield 1', 'The Last of Us', 'MineCraft', 'FIFA 15',
#        'God of War (PS4)', 'Horizon: Zero Dawn', 'Destiny',
#        'Uncharted: The Nathan Drake Collection',
#        'The Witcher 3: Wild Hunt', 'Final Fantasy XV',
#        'Crash Bandicoot N. Sane Trilogy', 'Monster Hunter: World',
#        'Overwatch', 'Star Wars Battlefront II (2017)',
#        "Tom Clancy's The Division", "Tom Clancy's Rainbow Six: Siege",
#        'Watch Dogs', 'Call of Duty: Ghosts', "Assassin's Creed: Unity",
#        'Destiny 2', 'Batman: Arkham Knight', "Assassin's Creed Origins",
#        'Far Cry 4', 'NBA 2K16', 'Far Cry 5', 'Battlefield 4',
# ...

# %%
df['Game'].nunique()
# Out:
# 824

# %%
df_sorted=df.sort_values(by='Global', ascending=False)
top_5_games=df_sorted.head()
top_5_games[['Game','Global']]
# Out:
#                         Game  Global
# 0         Grand Theft Auto V   19.39
# 1  Call of Duty: Black Ops 3   15.09
# 2      Red Dead Redemption 2   13.94
# 3         Call of Duty: WWII   13.40
# 4                    FIFA 18   11.80

# %%
#2.Compare regional sales for each genre to understand market prefences

# %%
df['Genre'].unique()
# Out:
# array(['Action', 'Shooter', 'Action-Adventure', 'Sports', 'Role-Playing',
#        'Misc', 'Platform', 'Racing', 'Fighting', 'Adventure', 'MMO',
#        'Simulation', 'Music', 'Party', 'Strategy', 'Puzzle',
#        'Visual Novel'], dtype=object)

# %%
df['Genre'].nunique()
# Out:
# 17

# %%
regions=['North America','Europe','Japan','Rest of World']
genres=df['Genre'].unique()
for region in regions:
    print(f"Region: {region}")
    for genre in genres:
        sales=df[df['Genre']==genre][region].sum().round(2)
        print(f"{genre}:{sales}")
    print()
# Out:
# Region: North America
# Action:48.15
# Shooter:50.5
# Action-Adventure:22.3
# Sports:33.31
# Role-Playing:22.15
# Misc:3.64
# Platform:5.48
# Racing:5.86
# Fighting:8.58
# Adventure:5.27
# MMO:1.32
# Simulation:1.47
# Music:2.4
# Party:0.09
# Strategy:0.57
# Puzzle:0.28
# Visual Novel:0.2
#
# Region: Europe
# Action:57.51
# Shooter:58.64
# Action-Adventure:27.79
# Sports:42.81
# Role-Playing:22.4
# Misc:6.03
# Platform:8.92
# Racing:14.77
# Fighting:6.11
# Adventure:6.08
# MMO:1.45
# Simulation:2.07
# Music:1.62
# Party:0.47
# Strategy:0.22
# Puzzle:0.16
# Visual Novel:0.02
#
# Region: Japan
# Action:10.27
# Shooter:4.42
# Action-Adventure:1.96
# Sports:1.83
# Role-Playing:9.33
# Misc:0.96
# Platform:0.67
# Racing:0.76
# Fighting:1.67
# Adventure:1.64
# MMO:0.2
# Simulation:0.28
# Music:0.17
# Party:0.0
# Strategy:0.34
# Puzzle:0.0
# Visual Novel:0.19
#
# Region: Rest of World
# Action:20.76
# Shooter:21.48
# Action-Adventure:9.83
# Sports:14.9
# Role-Playing:8.91
# Misc:1.85
# ...

# %%
#2.Compare regional sales for each genre to understand market prefences through visualization

# %%
regions=['North America','Europe','Japan','Rest of World']
df_melted=pd.melt(df,id_vars=['Genre'],value_vars=regions)
plt.figure(figsize=(20,5))
sns.barplot(x='Genre', y='value', hue='variable', data=df_melted)
plt.title('Regional Sales by Genre',fontsize=20)
plt.xlabel('Genre',fontsize=15)
plt.ylabel('Sales',fontsize=15)
plt.show()

# %%
#Comments:-The genre shooter has the highest sales from  Europe.

# %%
#3.Find the publisher with the highest total global sales

# %%
df['Publisher'].unique()
# Out:
# array(['Rockstar Games', 'Activision', 'EA Sports', 'Electronic Arts',
#        'Sony Interactive Entertainment', 'Bethesda Softworks',
#        'Sony Computer Entertainment', 'Namco Bandai Games', 'Square Enix',
#        'Capcom', 'Blizzard Entertainment', 'Ubisoft',
#        'Warner Bros. Interactive', '2K Sports',
#        'Warner Bros. Interactive Entertainment',
#        'Konami Digital Entertainment', '2K Games', 'Hello Games',
#        '505 Games', 'Deep Silver', 'Take-Two Interactive',
#        'Bandai Namco Games', 'Sega', 'Tecmo Koei', 'Gearbox Software',
#        'Mojang', 'Disney Interactive Studios', 'Focus Home Interactive',
#        'Studio Wildcard', 'Codemasters', 'Koch Media',
#        'Harmonix Music Systems', 'Rebellion Developments', 'Gun Media',
#        'Telltale Games', 'Kalypso Media', 'City Interactive',
#        'NIS America', 'Sold Out', 'Tripwire Interactive', 'PQube',
#        'THQ Nordic', 'Milestone S.r.l.', 'Nordic Games', 'Astragon',
# ...

# %%
df['Publisher'].nunique()
# Out:
# 152

# %%
df_sor=df.sort_values(by='Global', ascending=False)
top_game=df_sorted.head(1)
top_game[['Publisher','Global']]
# Out:
#         Publisher  Global
# 0  Rockstar Games   19.39

# %%
#4.Analyze the year with the highest no.of Game releases

# %%
df['Year'].unique()
# Out:
# array([2014., 2015., 2018., 2017., 2016., 2013., 2019., 2020.])

# %%
games_per_year = df.groupby('Year').size()
year_with_max_releases = games_per_year.idxmax()
max_releases = games_per_year.max()
print(f"The year with the highest number of game releases is {year_with_max_releases} with {max_releases} game releases.")
# Out:
# The year with the highest number of game releases is 2017.0 with 254 game releases.

# %%
#5.Determine the most popular genre globally based on total sales

# %%
genre_sales=df.groupby('Genre')['Global'].sum().reset_index()
genre_sales_1=genre_sales.sort_values('Global',ascending=False)
genre_sales_1.head(1)
# Out:
#     Genre  Global
# 0  Action  136.82

# %%
#6.Identify the game with the highest sales in Japan compared to other regions

# %%
df_sorted_by_japan = df.sort_values(by='Japan', ascending=False)
game_with_highest_japan_sales = df_sorted_by_japan.iloc[0]
game_with_highest_japan_sales_info = game_with_highest_japan_sales[['Game', 'Japan', 'North America', 'Europe', 'Rest of World', 'Global']]
print("Game with the highest sales in Japan:")
print(game_with_highest_japan_sales_info)
# Out:
# Game with the highest sales in Japan:
# Game             Monster Hunter: World
# Japan                             2.17
# North America                     1.03
# Europe                            1.06
# Rest of World                     0.42
# Global                            4.67
# Name: 24, dtype: object

# %%
#7.Examine if there is a correlation between sales in North America and Europe

# %%
correlation=df['North America'].corr(df['Europe'])
correlation
# Out:
# 0.8107281993891681

# %%
#Comments:-There is a strong positive correlation between sales in North America and Europe

# %%
#7.Correlatipon through visualization(Using Scatter Plot)

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['North America'],df['Europe'])
plt.plot([0,5],[0,5],'k--',label='y=x')
plt.title('Sales VS North America and Europe')
plt.xlabel('North America')
plt.ylabel('Europe')
plt.show()

# %%
#Comment:-As the data points are closely grouped along a straight line (upward or downward), it indicates a strong correlation.Thus there is a strong correlation between sales in North America and Europe

# %%
#8.Compare the sales growth trend for "Action" and "Shooter" genres over the years

# %%
filtered_df = df[df['Genre'].isin(['Action', 'Shooter'])]
sales_by_year_genre = filtered_df.groupby(['Year', 'Genre'])[['North America', 'Europe', 'Japan', 'Rest of World']].sum()
sales_by_year_genre['Global'] = sales_by_year_genre.sum(axis=1)
sales_by_year_genre = sales_by_year_genre.reset_index()
plt.figure(figsize=(12, 6))
for genre in ['Action', 'Shooter']:
    genre_data = sales_by_year_genre[sales_by_year_genre['Genre'] == genre]
    plt.plot(genre_data['Year'], genre_data['Global'], label=genre, marker='o')
plt.title('Sales Growth Trend for "Action" and "Shooter" Genres Over the Years', fontsize=15)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Global Sales', fontsize=10)
plt.show()

# %%
#9.Identify the top publisher in terms of sales for each region

# %%
reg=['North America','Europe', 'Japan','Rest of World']
#reg

# %%
for region in reg:
    top_publisher=df.groupby('Publisher')[region].sum().nlargest(1).index[0]
    print(f"{region}:{top_publisher}")
# Out:
# North America:Activision
# Europe:Activision
# Japan:Square Enix
# Rest of World:Activision

# %%
#10.Visualize the distribution of global sales to identify patterns and outliers

# %%
#Scatterplot(Trend)
plt.figure(figsize=(10,6))
sns.scatterplot(df['Global'])
plt.title('Global Sales Distribution')
plt.xlabel('Frequency')
plt.ylabel('Global sales')
plt.show()

# %%
#LineChart(Trend)
plt.figure(figsize=(10,6))
sns.lineplot(df['Global'])
plt.title('Global Sales Distribution')
plt.xlabel('Frequency')
plt.ylabel('Sales')
plt.show()

# %%
#BoxPlot(Outliers)
sns.boxplot(x=df['Global'])
# Out:
# <Axes: xlabel='Global'>

# %%
#11.Create Visualizations to better understanding and communicate data insights

# %%
#Distribution of Global sales(Histogram)

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['Global'],kde=True)
plt.title('Global Sales Distribution')
plt.xlabel('Global sales')
plt.ylabel('Frequency')
plt.show()

# %%
#Comments:- The distribution of Global Sales is positively skewed.

# %%
#Total Sales Comparion for Regions(Bar chatrt)

# %%
regions=['North America','Europe', 'Japan','Rest of World']
total_sales=df[regions].sum()
plt.figure(figsize=(5,10))
plt.bar(total_sales.index, total_sales.values)
plt.title('Sales distribution for Regions')
plt.xlabel('Region')
plt.ylabel('Sales')
plt.show()

# %%
#Share of total global sales by genre(pie_chart)

# %%
df.groupby('Genre')['Global'].sum().plot(kind='pie', figsize=(10,10),autopct='%1.1f%%')
plt.show()

# %%
#Trend of Global sales over the Year(Line Chart)

# %%
plt.figure(figsize=(8,8))
sns.lineplot(x=df["Global"], y=df["Year"], color='purple')
plt.show()

# %%
#Top 10 best-selling games globally (Horizontal bar chart)

# %%
df_sorted=df.sort_values(by='Global', ascending=False)
top_5_games=df_sorted.head(10)
top_5_games[['Game','Global']]
plt.figure(figsize=(10,6))
plt.barh(top_5_games['Game'],top_5_games['Global'], color='#89CFF0')
plt.title('Top 10 best-selling games globally',color='purple')
plt.xlabel('Games', color='green')
plt.ylabel('Global Sales',color='green')
plt.show()

# %%
#Correlation between regional sales(heatmap)

# %%
regional_sales=df[['North America','Europe','Japan','Rest of World','Global']].corr()
regional_sales
# Out:
#                North America    Europe     Japan  Rest of World    Global
# North America       1.000000  0.810728  0.389357       0.951630  0.936347
# Europe              0.810728  1.000000  0.359739       0.951293  0.961306
# Japan               0.389357  0.359739  1.000000       0.393824  0.448419
# Rest of World       0.951630  0.951293  0.393824       1.000000  0.997134
# Global              0.936347  0.961306  0.448419       0.997134  1.000000

# %%
sns.heatmap(regional_sales, cmap="YlGnBu", annot=True, fmt=".2f")
plt.show()

# %%
#Contribution of each genre to regional sales(stacked bar chart)

# %%
genre_sales = df.groupby('Genre')[['North America', 'Europe', 'Japan', 'Rest of World']].sum()
ax = genre_sales.plot(kind='bar', stacked=True, figsize=(10, 6))
ax.set_title('Contribution of Each Genre to Regional Sales', fontsize=14)
ax.set_xlabel('Genre')
ax.set_ylabel('Sales')
plt.show()

# %% [markdown]
# What Did I Learn from Analyzing the Data?
# 1. What insights or patterns did you discover during your analysis?
# Ans:
# The histogram shows that the distribution of Global Sales is not normalized, it is positively skewed.
#
# The bar chart shows that Europe generates the most sales compared to other regions.
#
# The pie chart is clearly showing that Action games have the largest slice,  it means the genres "Action"  is Dominant Genre in global sales.
#
# From Horizontal bar chart it is cleary shown that globally the game sold the most is: "Grand Theft Auto V".
#
# Heatmap is showing that there is weak correlation between regional sales.
#
# Stacked bar chart shows that the genre "Action" and then "Shooter" contributed the most in Regional Sales.

# %% [markdown]
# 2.Did anything in the data surprise you? If yes, what was it?
# Ans:
# Grand Theft Auto V participated the most globally
# The genre shooter has tha highest sales in North America
# Japan has distinct taste like role playing genre is topped in Japan
# Action and shooter games participated the most in sales

# %% [markdown]
# 3. What challenges did you face, and how did you overcome them?
# Ans: The primary challenges in analyzing the PS4 games sales data were related to data cleaning, handling missing or inconsistent values, choosing the right type of analysis, and interpreting the results in the context of industry trends. By using data preprocessing techniques, choosing appropriate visualizations, and applying thoughtful analysis, these challenges could be effectively overcome, resulting in meaningful insights about game sales, genre preferences, and market trends.

# %% [markdown]
# 4. How do you think data analysis can help in making real-world decisions?
# Ans:  I think that data analysis helps alot in making real-world decisions as we can visualize the data in such a better way through it, can extract meaning ful information from the data and also can see the trends by which we always proof to be helpful in making
# real-world decisions.

# %% [markdown]
# 5. What skills or knowledge do you feel you have improved during this project
# Ans: I learned alot from this project, this project helped me strengthen my technical skills in data cleaning, analysis, visualization, and statistical techniques, while also improving my domain knowledge of the gaming industry. I learned how to transform the data into valuable insights, make sense of trends, and communicate those findings clearly to different audiences.
